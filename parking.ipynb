# %% [markdown]
# ## Parking Lot

# %% [markdown]
# latar belakang :
# test tes tes

# %% [markdown]
# Link dataset: https://www.kaggle.com/datasets/blanderbuss/parking-lot-dataset

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
from matplotlib import pyplot as plt

# %%
datagen = ImageDataGenerator(
    rescale=1./255,
)

# %%
generator = datagen.flow_from_directory(
    'data/data parking',
    target_size=(150, 150),
    batch_size=32,
    class_mode='binary'
)
# Out:
# Found 91148 images belonging to 2 classes.

# %%
class_indices = generator.class_indices
classes = generator.classes
class_counts = {class_name: sum(classes == class_index) for class_name, class_index in class_indices.items()}
print(class_counts)
# Out:
# {'Empty': 43213, 'Occupied': 47935}

# %%
x_train, y_train = generator.next()

plt.figure(figsize=(20,10))
for i in range(7):
    plt.subplot(1,7,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap='gray')
    plt.xlabel(f"ID:{y_train[i]}")
plt.show()
